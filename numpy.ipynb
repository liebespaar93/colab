# %% [markdown]
# ## 메소드 와 함수 차이
# ## 함수 포인트와 출력의 차이
#
# ## 어트리뷰트 인스턴스 메서드 차이

# %%
import numpy as np

test = np.array([1, 3, 4, 5], dtype=complex)
test
# Out:
# numpy.ndarray

# %%
test.dtype
# Out:
# dtype('complex128')

# %%
test
# Out:
# array([[1.+0.j, 3.+0.j],
#        [4.+0.j, 5.+0.j]])
