# %% [markdown]
# # 1. 초기 설정을 입력해 주세요
#
#
#
# *   깃 이메일 기록
#     ```git config --global user.email '본인이메일'```
# *   깃 유저 이름 기록
#     ```git config --global user.name '본인이름'```

# %%
# !git config --global user.email 'liebespaar93@gmail.com'
# !git config --global user.name 'liebespaar93'

# %% [markdown]
# ## 2. Google drive 접속하기
#
# *   드라이브 위치 수정이 원할경우.
#   ``` mkdir '폴더이름' ```
#   ``` cd '폴더이름' ```.
#
#
# *   첫 브렌치라 오류가 있을시 [2-1] 브랜치 생성 생성 따라하기

# %%
from google.colab import drive

drive.mount('/content/drive/');
# Out:
# Mounted at /content/drive/

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/'
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %% [markdown]
# ## 3. git 생성하기
#
# *   github에 새로운 레포지토리 생성
# *   생성한 github 레포지토리 clone 하기
# *   생성한 git 들어가기

# %%
# !git clone https://github.com/liebespaar93/colab.git
# %cd ./colab

# %%
# !git checkout -t remotes/origin/google
# !git pull

# %% [markdown]
# ### 3-1. [주의] 브랜치가 없을때만 실행 바랍니다
#
# *   브랜치 생성 ```git checkout -b google```
# *   항목 추가 ```git push --set-upstream origin google```

# %%
# !git checkout -b google
# !git push --set-upstream https://{$token}@github.com/liebespaar93/colab.git

# %% [markdown]
# ## 4. git push 하기
#
# *   git token 만들기
#     [git token site](https://github.com/settings/tokens)
#
# *   커밋 메세지 작성하기
#     ```git commit -m "google colab commit"```
#
# *   토큰값을 입력하여 git push 를 작성한다
#     ``` git push https://{Token}@github.com/{git repo}/colab.git ```

# %%
# !git add .
# !git commit -m "google colab commit"
# !git push https://{token}@github.com/liebespaar93/colab.git
# Out:
# On branch google
# nothing to commit, working tree clean
# Everything up-to-date

# %% [markdown]
# ## 5. 환경 설정 이후 git push code

# %%
from google.colab import drive

drive.mount('/content/drive/');

# %cd '/content/drive/MyDrive/Colab Notebooks/colab'
# !git remote update
# !git checkout google
# !git pull
# Out:
# Mounted at /content/drive/
# /content/drive/MyDrive/Colab Notebooks/colab
# Fetching origin
# remote: Enumerating objects: 1, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 1 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (1/1), 641 bytes | 37.00 KiB/s, done.
# From https://github.com/liebespaar93/colab
#    9c9b5f3..2964f0c  google     -> origin/google
#    6c3e310..13b4a28  main       -> origin/main
# M	"airkorea_\341\204\200\341\205\251\341\206\274\341\204\200\341\205\265.ipynb"
# M	git_push.ipynb
# Already on 'google'
# From https://github.com/liebespaar93/colab
#  * branch            google     -> FETCH_HEAD
# Already up to date.

# %%
# !git config --global user.email 'liebespaar93@gmail.com'
# !git config --global user.name 'liebespaar93'

# %%
import json

with open ("/content/drive/MyDrive/path/to/git_token.json", "r", encoding="utf-8-sig") as json_file:
    jdata = json.load(json_file)
print(jdata['name'])
# Out:
# colab

# %%
# !git add .
# !git commit -m "google colab commit"

# !git push https://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@github.com/liebespaar93/colab.git
# Out:
# [google 2d5f95d] google colab commit
#  3 files changed, 3 insertions(+), 2 deletions(-)
#  rewrite "airkorea_\341\204\200\341\205\251\341\206\274\341\204\200\341\205\265.ipynb" (88%)
#  create mode 100644 colab_connect_firebase.ipynb
# fatal: could not read Password for 'https://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@github.com': No such device or address

# %%
# !env {jdata['name']}
# Out:
# env: ‘colab’: No such file or directory
