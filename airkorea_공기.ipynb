# %% [markdown]
# # 폰트 적용

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
import matplotlib as mpl
import matplotlib.pyplot as plt
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 16 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %%
# 경고(warning) 비표시
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.family'] = 'NanumBarunGothic' # 나눔바른고딕 적용하기

# %% [markdown]
# # 구글 드라이브 연동

# %%
from google.colab import drive

drive.mount('/content/drive/');
# %cd '/content/drive/MyDrive/Colab Notebooks/colab'
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/MyDrive/Colab Notebooks/colab

# %% [markdown]
# # 파이썬 인코딩 종류
#  [파이썬 공식 링크](https://docs.python.org/3/library/codecs.html#standard-encodings)
#
# -  cp949
#     949, ms949, uhc 지원
# -  euc_kr
#     euckr, korean, ksc5601, ks_c-5601, ks_c-5601-1987, ksx1001, ks_x-1001 지원
# -  iso2022_kr
#     csiso2022kr, iso2022kr, iso-2022-kr

# %%
# pd.read_csv('Ress-Case2.csv', encoding='ISO-8859-1')
# pd.read_csv('Ress-Case2.csv', encoding='CP949')
pd_file_csv = pd.read_csv('Ress-Case2.csv', encoding='euc-kr')
pd_file_csv
# Out:
#                     측정일시   측정소코드            측정소명 아황산가스 농도(ppm) 일산화탄소 농도(ppm)  \
# 0        2019-01-01 0:00  111121              중구         0.003           0.7
# 1        2019-01-01 0:00  111122            한강대로         0.004             1
# 2        2019-01-01 0:00  111123             종로구         0.003           0.7
# 3        2019-01-01 0:00  111124            청계천로         0.005           0.8
# 4        2019-01-01 0:00  111125              종로         0.003           0.7
# ...                  ...     ...             ...           ...           ...
# 912679  2019-03-31 23:00  831491             덕적도         0.001           0.1
# 912680  2019-03-31 23:00  831492             백령도         0.002           0.5
# 912681  2019-03-31 23:00  999901  공단이동차(본부)_0787         0.002           0.4
# 912682  2019-03-31 23:00  999904        수도권청이동차1             -             -
# 912683  2019-03-31 23:00  999906        수도권청이동차2             -             -
#
# ...

# %%
pd_file_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 912684 entries, 0 to 912683
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   측정일시                  912684 non-null  object
#  1   측정소코드                 912684 non-null  int64
#  2   측정소명                  912684 non-null  object
#  3   아황산가스 농도(ppm)         912684 non-null  object
#  4   일산화탄소 농도(ppm)         912684 non-null  object
#  5   오존 농도(ppm)            912684 non-null  object
#  6   이산화질소 농도(ppm)         912684 non-null  object
#  7   PM10 농도(㎍/㎥)          912684 non-null  object
#  8   PM25 농도(㎍/㎥)          912684 non-null  object
#  9   통합대기환경수치정보            912684 non-null  object
#  10  통합대기환경지수정보            841368 non-null  float64
#  11  아황산가스지수정보             876064 non-null  float64
#  12  일산화탄소지수정보             878355 non-null  float64
#  13  오존지수정보                882346 non-null  float64
# ...

# %%
pd_file_csv.info
# Out:
# <bound method DataFrame.info of                     측정일시   측정소코드            측정소명 아황산가스 농도(ppm) 일산화탄소 농도(ppm)  \
# 0        2019-01-01 0:00  111121              중구         0.003           0.7
# 1        2019-01-01 0:00  111122            한강대로         0.004             1
# 2        2019-01-01 0:00  111123             종로구         0.003           0.7
# 3        2019-01-01 0:00  111124            청계천로         0.005           0.8
# 4        2019-01-01 0:00  111125              종로         0.003           0.7
# ...                  ...     ...             ...           ...           ...
# 912679  2019-03-31 23:00  831491             덕적도         0.001           0.1
# 912680  2019-03-31 23:00  831492             백령도         0.002           0.5
# 912681  2019-03-31 23:00  999901  공단이동차(본부)_0787         0.002           0.4
# 912682  2019-03-31 23:00  999904        수도권청이동차1             -             -
# 912683  2019-03-31 23:00  999906        수도권청이동차2             -             -
#
# ...

# %%
pd_file_csv.isna().sum()
# Out:
# 측정일시                        0
# 측정소코드                       0
# 측정소명                        0
# 아황산가스 농도(ppm)               0
# 일산화탄소 농도(ppm)               0
# 오존 농도(ppm)                  0
# 이산화질소 농도(ppm)               0
# PM10 농도(㎍/㎥)                0
# PM25 농도(㎍/㎥)                0
# 통합대기환경수치정보                  0
# 통합대기환경지수정보              71316
# 아황산가스지수정보               36620
# 일산화탄소지수정보               34329
# 오존지수정보                  30338
# 이산화질소지수정보               21842
# PM10 24시간등급             28234
# PM25 24시간등급             75287
# PM10 24시간예측이동농도(㎍/㎥)        0
# PM25 24시간예측이동농도(㎍/㎥)        0
# PM10 1시간등급              22602
# PM25 1시간등급              64954
# 최종수정일시                      0
# dtype: int64

# %% [markdown]
# # null 데이터 날리기

# %%
pd_data_cleansing = pd_file_csv.isnull().sum().reset_index()
pd_data_cleansing.columns = ['column', 'count']

# %% [markdown]
# null비율 확인

# %%
pd_data_cleansing['ratio'] = (pd_data_cleansing['count'] / pd_file_csv.shape[0]) * 100
pd_data_cleansing
# Out:
#                   column  count     ratio
# 0                   측정일시      0  0.000000
# 1                  측정소코드      0  0.000000
# 2                   측정소명      0  0.000000
# 3          아황산가스 농도(ppm)      0  0.000000
# 4          일산화탄소 농도(ppm)      0  0.000000
# 5             오존 농도(ppm)      0  0.000000
# 6          이산화질소 농도(ppm)      0  0.000000
# 7           PM10 농도(㎍/㎥)      0  0.000000
# 8           PM25 농도(㎍/㎥)      0  0.000000
# 9             통합대기환경수치정보      0  0.000000
# 10            통합대기환경지수정보  71316  7.813876
# 11             아황산가스지수정보  36620  4.012342
# 12             일산화탄소지수정보  34329  3.761324
# 13                오존지수정보  30338  3.324042
# 14             이산화질소지수정보  21842  2.393161
# 15           PM10 24시간등급  28234  3.093513
# 16           PM25 24시간등급  75287  8.248967
# 17  PM10 24시간예측이동농도(㎍/㎥)      0  0.000000
# 18  PM25 24시간예측이동농도(㎍/㎥)      0  0.000000
# 19            PM10 1시간등급  22602  2.476432
# 20            PM25 1시간등급  64954  7.116812
# ...

# %%
pd_data_cleansing.loc[pd_data_cleansing['ratio'] != 0]
# Out:
#          column  count     ratio
# 10   통합대기환경지수정보  71316  7.813876
# 11    아황산가스지수정보  36620  4.012342
# 12    일산화탄소지수정보  34329  3.761324
# 13       오존지수정보  30338  3.324042
# 14    이산화질소지수정보  21842  2.393161
# 15  PM10 24시간등급  28234  3.093513
# 16  PM25 24시간등급  75287  8.248967
# 19   PM10 1시간등급  22602  2.476432
# 20   PM25 1시간등급  64954  7.116812

# %%
import missingno as msno
fig = msno.matrix(pd_file_csv, color=(0, 1, 0))

# %%
pd_data_cleansing = pd_file_csv.dropna(axis=0)
fig = msno.matrix(pd_data_cleansing, color=(0, 1, 0))

# %%
pd_data_cleansing["아황산가스 농도(ppm)"].unique()
# Out:
# array(['0.003', '0.004', '0.005', '0.002', '0.006', '0.008', '-', '0.007',
#        '0.009', '0.01', '0.001', '0.013', '0.015', '0', '0.011', '0.012',
#        '0.014', '0.019', '0.025', '0.017', '0.018', '0.016', '0.023',
#        '0.031', '0.022', '0.021', '0.028', '0.0014', '0.0017', '0.029',
#        '0.0013', '0.0015', '0.0009', '0.0023', '0.02', '0.037', '0.024',
#        '0.036', '0.033', '0.045', '0.034', '0.047', '0.035', '0.027',
#        '0.041', '0.032', '0.039', '0.048', '0.026', '0.03', '0.054',
#        '0.051', '0.04', '0.038', '0.05', '0.043', '0.044', '0.0062',
#        '0.0012', '0.052', '0.049', '0.064', '0.067', '0.055', '0.056',
#        '0.071', '0.058', '0.062', '0.042', '0.046', '0.057', '0.053',
#        '0.091', '0.066', '0.059', '0.061', '0.06', '0.079', '0.0026',
#        '0.0003', '0.0005', '0.0025', '0.0027', '0.0019', '0.07', '0.09',
#        '0.108', '0.088', '0.069', '0.073', '0.063', '0.065', '0.068',
#        '0.092'], dtype=object)

# %%
pd_data_clean = pd.DataFrame()
for col in pd_file_csv.columns:
  pd_data_clean[col] = pd_file_csv[col].drop(pd_file_csv[pd_file_csv[col]=='-'].index)
pd_data_clean = pd_data_clean.dropna(axis=0)
pd_data_clean["아황산가스 농도(ppm)"].unique()
# Out:
# array(['0.003', '0.004', '0.005', '0.002', '0.006', '0.008', '0.007',
#        '0.009', '0.01', '0.001', '0.013', '0.015', '0', '0.011', '0.012',
#        '0.014', '0.019', '0.025', '0.017', '0.018', '0.016', '0.023',
#        '0.031', '0.022', '0.021', '0.028', '0.0014', '0.0017', '0.029',
#        '0.0013', '0.0015', '0.0009', '0.0023', '0.02', '0.037', '0.024',
#        '0.036', '0.033', '0.045', '0.034', '0.047', '0.035', '0.027',
#        '0.041', '0.032', '0.039', '0.048', '0.026', '0.03', '0.054',
#        '0.051', '0.04', '0.038', '0.05', '0.043', '0.044', '0.0062',
#        '0.0012', '0.052', '0.049', '0.064', '0.067', '0.055', '0.056',
#        '0.071', '0.058', '0.062', '0.042', '0.046', '0.057', '0.053',
#        '0.091', '0.066', '0.059', '0.061', '0.06', '0.079', '0.0026',
#        '0.0003', '0.0005', '0.0025', '0.0027', '0.0019', '0.07', '0.09',
#        '0.108', '0.088', '0.069', '0.073', '0.063', '0.065', '0.068',
#        '0.092'], dtype=object)

# %%
pd_data_clean["아황산가스 농도(ppm)"] = pd_data_clean["아황산가스 농도(ppm)"].astype(float)
pd_data_clean["일산화탄소 농도(ppm)"] = pd_data_clean["일산화탄소 농도(ppm)"].astype(float)
pd_data_clean["오존 농도(ppm)"] = pd_data_clean["오존 농도(ppm)"].astype(float)
pd_data_clean["이산화질소 농도(ppm)"] = pd_data_clean["이산화질소 농도(ppm)"].astype(float)
pd_data_clean["아황산가스 농도(ppm)"] = pd_data_clean["아황산가스 농도(ppm)"].astype(float)
pd_data_clean["통합대기환경수치정보"] = pd_data_clean["통합대기환경수치정보"].astype(float)
pd_data_clean["PM10 농도(㎍/㎥)"] = pd_data_clean["PM10 농도(㎍/㎥)"].astype(float)
pd_data_clean["PM25 농도(㎍/㎥)"] = pd_data_clean["PM25 농도(㎍/㎥)"].astype(float)
pd_data_clean["PM10 24시간예측이동농도(㎍/㎥)"] = pd_data_clean["PM10 24시간예측이동농도(㎍/㎥)"].astype(float)
pd_data_clean["PM25 24시간예측이동농도(㎍/㎥)"] = pd_data_clean["PM25 24시간예측이동농도(㎍/㎥)"].astype(float)

# %%
pd_data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 785531 entries, 0 to 912681
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   측정일시                  785531 non-null  object
#  1   측정소코드                 785531 non-null  int64
#  2   측정소명                  785531 non-null  object
#  3   아황산가스 농도(ppm)         785531 non-null  float64
#  4   일산화탄소 농도(ppm)         785531 non-null  float64
#  5   오존 농도(ppm)            785531 non-null  float64
#  6   이산화질소 농도(ppm)         785531 non-null  float64
#  7   PM10 농도(㎍/㎥)          785531 non-null  float64
#  8   PM25 농도(㎍/㎥)          785531 non-null  float64
#  9   통합대기환경수치정보            785531 non-null  float64
#  10  통합대기환경지수정보            785531 non-null  float64
#  11  아황산가스지수정보             785531 non-null  float64
#  12  일산화탄소지수정보             785531 non-null  float64
#  13  오존지수정보                785531 non-null  float64
# ...

# %%
sns.pairplot(pd_data_clean)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
sns.heatmap(pd_data_clean.corr(),annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # 분류

# %%
x = pd_data_clean[['아황산가스 농도(ppm)', '일산화탄소 농도(ppm)', '오존 농도(ppm)', '이산화질소 농도(ppm)', 'PM10 농도(㎍/㎥)', 'PM25 농도(㎍/㎥)']]
y = pd_data_clean[['통합대기환경수치정보']]

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 785531 entries, 0 to 912681
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   아황산가스 농도(ppm)  785531 non-null  float64
#  1   일산화탄소 농도(ppm)  785531 non-null  float64
#  2   오존 농도(ppm)     785531 non-null  float64
#  3   이산화질소 농도(ppm)  785531 non-null  float64
#  4   PM10 농도(㎍/㎥)   785531 non-null  float64
#  5   PM25 농도(㎍/㎥)   785531 non-null  float64
# dtypes: float64(6)
# memory usage: 42.0 MB

# %%
from sklearn import model_selection

x_train, x_test, y_train, y_test = model_selection.train_test_split(x, y, test_size=0.2, random_state = 42)

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (628424, 6)
# (628424, 1)

# %%
from sklearn.linear_model import LinearRegression
mlr = LinearRegression()
mlr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x.values)
x = pd.DataFrame(x_scaled)
x.columns = ['아황산가스 농도(ppm)', '일산화탄소 농도(ppm)', '오존 농도(ppm)', '이산화질소 농도(ppm)', 'PM10 농도(㎍/㎥)', 'PM25 농도(㎍/㎥)']

# %%
x.head()
# Out:
#    아황산가스 농도(ppm)  일산화탄소 농도(ppm)  오존 농도(ppm)  이산화질소 농도(ppm)  PM10 농도(㎍/㎥)  \
# 0      -0.473479       0.361067   -1.329808       1.688807     -0.603848
# 1      -0.087462       1.427116   -1.329808       2.623299     -0.548873
# 2      -0.473479       0.361067   -1.272104       1.279967     -0.741286
# 3       0.298555       0.716417   -1.329808       2.039242     -0.851237
# 4      -0.473479       0.361067   -1.329808       1.163155     -0.658823
#
#    PM25 농도(㎍/㎥)
# 0     -0.440883
# 1     -0.440883
# 2     -0.584656
# 3     -0.512769
# 4     -0.548713

# %%
x.describe()
# Out:
#        아황산가스 농도(ppm)  일산화탄소 농도(ppm)    오존 농도(ppm)  이산화질소 농도(ppm)  \
# count   7.855310e+05   7.855310e+05  7.855310e+05   7.855310e+05
# mean   -5.742732e-16  -8.243599e-16 -1.528308e-16  -1.968275e-16
# std     1.000001e+00   1.000001e+00  1.000001e+00   1.000001e+00
# min    -1.631530e+00  -2.126380e+00 -1.502921e+00  -1.465103e+00
# 25%    -4.734792e-01  -7.049816e-01 -8.681756e-01  -7.642340e-01
# 50%    -8.746216e-02  -3.496321e-01 -6.031827e-02  -2.969881e-01
# 75%     2.985549e-01   3.610670e-01  6.898350e-01   5.790980e-01
# max     4.005831e+01   2.736763e+01  7.498918e+00   1.132575e+01
#
#        PM10 농도(㎍/㎥)  PM25 농도(㎍/㎥)
# count  7.855310e+05  7.855310e+05
# mean   1.273590e-17 -7.873100e-17
# std    1.000001e+00  1.000001e+00
# min   -1.648378e+00 -1.303522e+00
# 25%   -6.863110e-01 -6.565424e-01
# 50%   -2.739967e-01 -2.971095e-01
# 75%    4.131937e-01  3.498696e-01
# max    1.052864e+01  8.113620e+00

# %% [markdown]
# # 테스트 데이터, 트레이닝 데이터

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state = 42)

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (628424, 6)
# (628424, 1)

# %%
from sklearn.linear_model import LinearRegression
mlr = LinearRegression()
mlr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
coef = pd.DataFrame(mlr.coef_.reshape(-1,1))

# %%
coef["columns"] = x_train.columns
coef
# Out:
#            0        columns
# 0  -1.235962  아황산가스 농도(ppm)
# 1   1.233560  일산화탄소 농도(ppm)
# 2   8.369337     오존 농도(ppm)
# 3   7.279004  이산화질소 농도(ppm)
# 4  20.167984   PM10 농도(㎍/㎥)
# 5  44.862642   PM25 농도(㎍/㎥)

# %%
## 5th row data => real value : 0.112903
curr_stat = np.array(x_train.iloc[100]).reshape(1,-1)
pred = mlr.predict(curr_stat)
print(pred)
print(y_train.iloc[100])
# Out:
# [[99.94618632]]
# 통합대기환경수치정보    92.0
# Name: 277477, dtype: float64

# %%
y_train.mean()
# Out:
# 통합대기환경수치정보    114.095607
# dtype: float64

# %%
y_predict = mlr.predict(x_test)
y_predict
# Out:
# array([[113.17472599],
#        [ 72.29110137],
#        [ 53.85083515],
#        ...,
#        [ 57.32335292],
#        [ 72.70902767],
#        [ 79.09744677]])

# %%
plt.scatter(y_test, y_predict, alpha=0.4)
plt.xlabel("Actual Status")
plt.ylabel("Predicted Satus")
plt.title("MULTIPLE LINEAR REGRESSION")
plt.show()

# %%
print(mlr.score(x_train, y_train))
# Out:
# 0.7901883491761462

# %%
from sklearn import metrics
x_train_pred = mlr.predict(x_train)
x_test_pred = mlr.predict(x_test)
print('RMSE train data: %.3f, RMSE test data: %.3f, MAE train data: %.3f, MAE test data: %.3f' %
      (np.sqrt(metrics.mean_squared_error(x_train_pred, y_train)),
       np.sqrt(metrics.mean_squared_error(x_test_pred, y_test)),
       metrics.mean_absolute_error(x_train_pred, y_train),
       metrics.mean_absolute_error(x_test_pred, y_test)))
print('R2 train data: %.3f, R2 test data: %.3f' %
      (metrics.r2_score(y_train,x_train_pred),
       metrics.r2_score(y_test,x_test_pred)))
# Out:
# RMSE train data: 34.119, RMSE test data: 34.109, MAE train data: 23.408, MAE test data: 23.394
# R2 train data: 0.790, R2 test data: 0.792

# %%
from sklearn.ensemble import RandomForestRegressor as rfr
Rfr = rfr(n_estimators = 1000, criterion = 'squared_error',
                              random_state = 42,
                              n_jobs = -1,
          max_depth = 5)
Rfr.fit(x_train,y_train)
x_train_pred = Rfr.predict(x_train)
x_test_pred = Rfr.predict(x_test)

print('RMSE train data: %.3f, RMSE test data: %.3f, MAE train data: %.3f, MAE test data: %.3f' %
      (np.sqrt(metrics.mean_squared_error(x_train_pred, y_train)),
       np.sqrt(metrics.mean_squared_error(x_test_pred, y_test)),
       metrics.mean_absolute_error(x_train_pred, y_train),
       metrics.mean_absolute_error(x_test_pred, y_test)))
print('R2 train data: %.3f, R2 test data: %.3f' %
      (metrics.r2_score(y_train,x_train_pred),
       metrics.r2_score(y_test,x_test_pred)))
# Out:
# RMSE train data: 31.053, RMSE test data: 31.106, MAE train data: 19.370, MAE test data: 19.406
# R2 train data: 0.826, R2 test data: 0.827

# %%
pd.DataFrame(np.hstack((np.array(x.columns).reshape(len(x.columns),1), Rfr.feature_importances_.reshape(len(x.columns),1))))
# Out:
#                0         1
# 0  아황산가스 농도(ppm)       0.0
# 1  일산화탄소 농도(ppm)       0.0
# 2     오존 농도(ppm)  0.000091
# 3  이산화질소 농도(ppm)   0.00519
# 4   PM10 농도(㎍/㎥)  0.032553
# 5   PM25 농도(㎍/㎥)  0.962166

# %%
from keras import models
from keras import layers

learning_rate = 0.001
epoch = 200
batch = 32

def build_model():
  model = models.Sequential()
  model.add(layers.Dense(100, activation='relu', input_shape=(x_train.shape[1],)))
  model.add(layers.Dense(100, activation='relu'))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(1))
  return model

model = build_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 100)               700
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_2 (Dense)             (None, 1)                 101
#
# ...
# Total params: 10,901
# Trainable params: 10,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
from keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss', patience=20)
history = model.fit(x_train, y_train, epochs=200, validation_split=0.2, callbacks=[early_stop])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(history.history['mae'], label='train mae')
plt.plot(history.history['val_mae'], label='val mae')
plt.xlabel('epoch')
plt.ylabel('mae')
plt.legend(loc='best')
plt.ylim([0, 100])
plt.show()

# %%
test_loss, test_mae = model.evaluate(x_test, y_test)
